# %%
from pyspark.sql import functions as f

from genpm.utils.consts import SHARED_DIR_PATH
from genpm.utils.utils import SparkDataManager

# use spark session if needed

sdm = SparkDataManager()

PREPROCESSED_DATASET_PATH = SHARED_DIR_PATH / "preprocessed_dataset"

# %%
df = sdm.read_parquet(PREPROCESSED_DATASET_PATH / "final" / "pm_df_long_indexed_winds")

# %%
df.printSchema()

# %%
dff = sdm.read_parquet(PREPROCESSED_DATASET_PATH / "simple_reports")

# %%
dff.printSchema()

# %%
dff.filter(f.col("bts_id") == "bts_33").show()
