# %%
from pyspark.sql import functions as f

from genpm.utils.consts import SHARED_DIR_PATH
from genpm.utils.spark_session import SparkDataManager
import pandas as pd


# use spark session if needed

sdm = SparkDataManager()

# %%
pm = sdm.read_parquet("/home/miklep2163/app/apps/apps/generator/data/shared_dir/preprocessed_dataset/final_scaled_only_minmax/pm_df_wide_indexed_winds")

# %%
pm.printSchema()

# %%
import pandas as pd
from genpm.utils.consts import SHARED_DIR_PATH

generated = pd.read_parquet(SHARED_DIR_PATH / "generated" / "bts_24_cell_5_2024-01-15.parquet")
generated
